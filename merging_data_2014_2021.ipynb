# %% [markdown]
# <a href="https://colab.research.google.com/github/sur-sakthy/da-dm-project/blob/main/merging_data_2014_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Trend Analysis **
# Load all data 2014 to 2020
#
# Datasets are coming from https://data.gov.ie/dataset/ipdc-waiting-list-by-group-hospital?package_type=dataset

# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#data mining and regression basic packages 
import pandas as pd
import numpy as np
from sklearn import preprocessing
import seaborn as sns
from statsmodels.compat import lzip
import statsmodels.formula.api as sm
import statsmodels.stats.stattools as st
import statsmodels.stats.api as sms
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import os 
import matplotlib.pyplot as plt

# %% [markdown]
# **Load in all data between 2014 - 2021 **

# %%
#2014- https://drive.google.com/file/d/1KJI8vte8n-tnjvceLu7iEyaYN4Duy8lH/view?usp=sharing
downloaded = drive.CreateFile({'id':'1KJI8vte8n-tnjvceLu7iEyaYN4Duy8lH'}) 
downloaded.GetContentFile('IPDC Waiting List By Group Hospital 2014.csv')  
data2014 = data = pd.read_csv('IPDC Waiting List By Group Hospital 2014.csv')
data2014 #35049 rows × 11 columns
# Out:
#       Archive Date                                  Group  ...    Time Bands Count
# 0       2014-01-30              Children's Hospital Group  ...    0-3 Months     5
# 1       2014-01-30              Children's Hospital Group  ...    3-6 Months     4
# 2       2014-01-30              Children's Hospital Group  ...    0-3 Months     4
# 3       2014-01-30              Children's Hospital Group  ...    3-6 Months     2
# 4       2014-01-30              Children's Hospital Group  ...    0-3 Months    12
# ...            ...                                    ...  ...           ...   ...
# 35044   2014-12-23  University of Limerick Hospital Group  ...    0-3 Months    44
# 35045   2014-12-23  University of Limerick Hospital Group  ...    3-6 Months    21
# 35046   2014-12-23  University of Limerick Hospital Group  ...    6-9 Months    13
# 35047   2014-12-23  University of Limerick Hospital Group  ...   9-12 Months     9
# ...

# %%
#2015- https://drive.google.com/file/d/1wYzwzLOhrVpIz6bOb0i-x-G2wU_glFht/view?usp=sharing
downloaded = drive.CreateFile({'id':'1wYzwzLOhrVpIz6bOb0i-x-G2wU_glFht'}) 
downloaded.GetContentFile('IPDC Waiting List By Group Hospital 2015.csv')  
data2015 = data = pd.read_csv('IPDC Waiting List By Group Hospital 2015.csv')
data2015 #43884 rows × 11 columns
# Out:
#       Archive Date                                  Group  ...    Time Bands Count
# 0       2015-01-29              Children's Hospital Group  ...    0-3 Months     1
# 1       2015-01-29              Children's Hospital Group  ...    0-3 Months     6
# 2       2015-01-29              Children's Hospital Group  ...    3-6 Months     3
# 3       2015-01-29              Children's Hospital Group  ...    0-3 Months    22
# 4       2015-01-29              Children's Hospital Group  ...    3-6 Months     1
# ...            ...                                    ...  ...           ...   ...
# 43879   2015-12-31  University of Limerick Hospital Group  ...   9-12 Months    32
# 43880   2015-12-31  University of Limerick Hospital Group  ...    0-3 Months    31
# 43881   2015-12-31  University of Limerick Hospital Group  ...    3-6 Months    27
# 43882   2015-12-31  University of Limerick Hospital Group  ...    6-9 Months    10
# ...

# %%
#2016- https://drive.google.com/file/d/1NOHqg3Z-ZPBvxEEpmJ9uJlt4Utsxnqis/view?usp=sharing
downloaded = drive.CreateFile({'id':'1NOHqg3Z-ZPBvxEEpmJ9uJlt4Utsxnqis'}) 
downloaded.GetContentFile('IPDC Waiting List By Group Hospital 2016.csv')  
data2016 = data = pd.read_csv('IPDC Waiting List By Group Hospital 2016.csv')
data2016 #49695 rows × 11 columns
# Out:
#       Archive Date                                  Group  ...    Time Bands Count
# 0       28/01/2016              Children's Hospital Group  ...    0-3 Months     3
# 1       28/01/2016              Children's Hospital Group  ...    3-6 Months     1
# 2       28/01/2016              Children's Hospital Group  ...    0-3 Months     3
# 3       28/01/2016              Children's Hospital Group  ...    3-6 Months     3
# 4       28/01/2016              Children's Hospital Group  ...    6-9 Months     1
# ...            ...                                    ...  ...           ...   ...
# 49690   30/12/2016  University of Limerick Hospital Group  ...    0-3 Months    43
# 49691   30/12/2016  University of Limerick Hospital Group  ...    3-6 Months    21
# 49692   30/12/2016  University of Limerick Hospital Group  ...    6-9 Months    16
# 49693   30/12/2016  University of Limerick Hospital Group  ...   9-12 Months    10
# ...

# %%
#2017- https://drive.google.com/file/d/1vAJFHASegdorHFA8hoaSOkLHTBThWemV/view?usp=sharing
downloaded = drive.CreateFile({'id':'1vAJFHASegdorHFA8hoaSOkLHTBThWemV'}) 
downloaded.GetContentFile('IPDC Waiting List By Group Hospital 2017.csv')  
data2017 = data = pd.read_csv('IPDC Waiting List By Group Hospital 2017.csv')
data2017 #54303 rows × 11 columns
# Out:
#       Archive Date                                  Group  ...    Time Bands Count
# 0       31/01/2017              Children's Hospital Group  ...    0-3 Months     3
# 1       31/01/2017              Children's Hospital Group  ...    3-6 Months     1
# 2       31/01/2017              Children's Hospital Group  ...    6-9 Months     1
# 3       31/01/2017              Children's Hospital Group  ...   9-12 Months     1
# 4       31/01/2017              Children's Hospital Group  ...  12-15 Months     2
# ...            ...                                    ...  ...           ...   ...
# 54298   29/12/2017  University of Limerick Hospital Group  ...    3-6 Months    23
# 54299   29/12/2017  University of Limerick Hospital Group  ...    6-9 Months    16
# 54300   29/12/2017  University of Limerick Hospital Group  ...   9-12 Months    19
# 54301   29/12/2017  University of Limerick Hospital Group  ...  12-15 Months    15
# ...

# %%
#2018- https://drive.google.com/file/d/1DHb9ww91z7hbEotAw0YveUWA5uILC1_r/view?usp=sharing
downloaded = drive.CreateFile({'id':'1DHb9ww91z7hbEotAw0YveUWA5uILC1_r'}) 
downloaded.GetContentFile('IPDC Waiting List By Group Hospital 2018.csv')  
data2018 = data = pd.read_csv('IPDC Waiting List By Group Hospital 2018.csv')
data2018 #55377 rows × 11 columns
# Out:
#       Archive Date                                  Group  ...     Time Bands Count
# 0       31/01/2018              Children's Hospital Group  ...     6-9 Months     1
# 1       31/01/2018              Children's Hospital Group  ...    9-12 Months     1
# 2       31/01/2018              Children's Hospital Group  ...     3-6 Months     1
# 3       31/01/2018              Children's Hospital Group  ...   12-15 Months     1
# 4       31/01/2018              Children's Hospital Group  ...     0-3 Months    14
# ...            ...                                    ...  ...            ...   ...
# 55372   20/12/2018  University of Limerick Hospital Group  ...    9-12 Months    18
# 55373   20/12/2018  University of Limerick Hospital Group  ...     0-3 Months    43
# 55374   20/12/2018  University of Limerick Hospital Group  ...     3-6 Months    27
# 55375   20/12/2018  University of Limerick Hospital Group  ...     6-9 Months    12
# ...

# %%
#2019- https://drive.google.com/file/d/1eVeEjG0HL6fqN1YAlD0IMGx20UI0PUel/view?usp=sharing
downloaded = drive.CreateFile({'id':'1eVeEjG0HL6fqN1YAlD0IMGx20UI0PUel'}) 
downloaded.GetContentFile('IPDC Waiting List By Group Hospital 2019.csv')  
data2019 = data = pd.read_csv('IPDC Waiting List By Group Hospital 2019.csv')
data2019 #52415 rows × 11 columns
# Out:
#       Archive Date                                  Group  ...     Time Bands Count
# 0       31/01/2019              Children's Health Ireland  ...     0-3 Months     9
# 1       31/01/2019              Children's Health Ireland  ...     3-6 Months    10
# 2       31/01/2019              Children's Health Ireland  ...     3-6 Months     1
# 3       31/01/2019              Children's Health Ireland  ...     0-3 Months     6
# 4       31/01/2019              Children's Health Ireland  ...     3-6 Months     3
# ...            ...                                    ...  ...            ...   ...
# 52410   19/12/2019  University of Limerick Hospital Group  ...    9-12 Months    14
# 52411   19/12/2019  University of Limerick Hospital Group  ...     0-3 Months    61
# 52412   19/12/2019  University of Limerick Hospital Group  ...     3-6 Months    23
# 52413   19/12/2019  University of Limerick Hospital Group  ...     6-9 Months    13
# ...

# %%
#2020- https://drive.google.com/file/d/1dMvJd11rH-ZytvI72bNm3hBitYjNZJTq/view?usp=sharing
downloaded = drive.CreateFile({'id':'1dMvJd11rH-ZytvI72bNm3hBitYjNZJTq'}) 
downloaded.GetContentFile('IPDC Waiting List By Group Hospital 2020.csv')  
data2020 = data = pd.read_csv('IPDC Waiting List By Group Hospital 2020.csv')
data2020 #58457 rows × 11 columns
# Out:
#       Archive Date                                  Group  ...     Time Bands Count
# 0       30/01/2020              Children's Health Ireland  ...     0-3 Months     5
# 1       30/01/2020              Children's Health Ireland  ...     3-6 Months     1
# 2       30/01/2020              Children's Health Ireland  ...    9-12 Months     2
# 3       30/01/2020              Children's Health Ireland  ...   12-15 Months     2
# 4       30/01/2020              Children's Health Ireland  ...     0-3 Months     1
# ...            ...                                    ...  ...            ...   ...
# 58452   23/12/2020  University of Limerick Hospital Group  ...     6-9 Months    10
# 58453   23/12/2020  University of Limerick Hospital Group  ...    9-12 Months    37
# 58454   23/12/2020  University of Limerick Hospital Group  ...   12-15 Months    36
# 58455   23/12/2020  University of Limerick Hospital Group  ...   15-18 Months    15
# ...

# %%
#2021- https://drive.google.com/file/d/1RpHGASGEw1jzWxFbUgO5GFbVZXIHC4fc/view?usp=sharing
downloaded = drive.CreateFile({'id':'1RpHGASGEw1jzWxFbUgO5GFbVZXIHC4fc'}) 
downloaded.GetContentFile('IPDC Waiting List By Group Hospital 2021.csv')  
data2021 = data = pd.read_csv('IPDC Waiting List By Group Hospital 2021.csv')
data2021 #15887 rows × 11 columns
# Out:
#       Archive Date                                  Group  ...     Time Bands Count
# 0       28/01/2021              Children's Health Ireland  ...     3-6 Months     2
# 1       28/01/2021              Children's Health Ireland  ...    9-12 Months     1
# 2       28/01/2021              Children's Health Ireland  ...     18+ Months     1
# 3       28/01/2021              Children's Health Ireland  ...     6-9 Months     1
# 4       28/01/2021              Children's Health Ireland  ...     0-3 Months     3
# ...            ...                                    ...  ...            ...   ...
# 15882   25/03/2021  University of Limerick Hospital Group  ...    9-12 Months    10
# 15883   25/03/2021  University of Limerick Hospital Group  ...   12-15 Months    34
# 15884   25/03/2021  University of Limerick Hospital Group  ...   15-18 Months    33
# 15885   25/03/2021  University of Limerick Hospital Group  ...     18+ Months    37
# ...

# %% [markdown]
# **Merge into one big dataset 2014-2021**
# 1. Merge side by side = Merge or join
# 2. Merge by stacking them together =concat or append

# %%
merged=pd.concat([data2014,data2015,data2016,data2017,data2018,data2019,data2020,data2021],ignore_index=True) #recount the numbers 
merged
# Out:
#        Archive Date  ... Count
# 0        2014-01-30  ...     5
# 1        2014-01-30  ...     4
# 2        2014-01-30  ...     4
# 3        2014-01-30  ...     2
# 4        2014-01-30  ...    12
# ...             ...  ...   ...
# 365062   25/03/2021  ...    10
# 365063   25/03/2021  ...    34
# 365064   25/03/2021  ...    33
# 365065   25/03/2021  ...    37
# 365066   25/03/2021  ...     1
#
# [365067 rows x 11 columns]

# %% [markdown]
# # Export to file

# %%
merged
# Out:
#        Archive Date  ... Count
# 0        2014-01-30  ...     5
# 1        2014-01-30  ...     4
# 2        2014-01-30  ...     4
# 3        2014-01-30  ...     2
# 4        2014-01-30  ...    12
# ...             ...  ...   ...
# 365062   25/03/2021  ...    10
# 365063   25/03/2021  ...    34
# 365064   25/03/2021  ...    33
# 365065   25/03/2021  ...    37
# 365066   25/03/2021  ...     1
#
# [365067 rows x 11 columns]

# %%
merged.to_csv("merged.csv",index=False)

# %%
#Check on all files within merged.csv 
! ls
# Out:
#  adc.json
# 'IPDC Waiting List By Group Hospital 2014.csv'
# 'IPDC Waiting List By Group Hospital 2015.csv'
# 'IPDC Waiting List By Group Hospital 2016.csv'
# 'IPDC Waiting List By Group Hospital 2017.csv'
# 'IPDC Waiting List By Group Hospital 2018.csv'
# 'IPDC Waiting List By Group Hospital 2019.csv'
# 'IPDC Waiting List By Group Hospital 2020.csv'
# 'IPDC Waiting List By Group Hospital 2021.csv'
#  merged.csv
#  sample_data

# %%
#get ready and download the merged file into CSV 
! cat merged.csv
# Out:
# Streaming output truncated to the last 5000 lines.
# 2014-05-29,Dublin Midlands Hospital Group,1270,Tallaght Hospital,7800,Urology,Inpatient,Adult,65+, 9-12 Months,1
# 2014-05-29,Dublin Midlands Hospital Group,1270,Tallaght Hospital,8000,Anaesthetics,Day Case,Adult,16-64, 0-3 Months,10
# 2014-05-29,Dublin Midlands Hospital Group,1270,Tallaght Hospital,8000,Anaesthetics,Day Case,Adult,16-64, 3-6 Months,2
# 2014-05-29,Dublin Midlands Hospital Group,1270,Tallaght Hospital,8000,Anaesthetics,Day Case,Adult,16-64, 6-9 Months,1
# 2014-05-29,Dublin Midlands Hospital Group,1270,Tallaght Hospital,8000,Anaesthetics,Day Case,Adult,65+, 0-3 Months,3
# 2014-05-29,Dublin Midlands Hospital Group,1270,Tallaght Hospital,8000,Anaesthetics,Day Case,Adult,65+, 3-6 Months,1
# 2014-05-29,Dublin Midlands Hospital Group,1270,Tallaght Hospital,8000,Anaesthetics,Inpatient,Adult,16-64, 3-6 Months,1
# ...
